# %% [markdown]
# # Introduction

# %% [markdown]
# Street Signs Taipei is an experiment into the documentation of street signs in an effort to understand and research living multilingualism in our environment.
