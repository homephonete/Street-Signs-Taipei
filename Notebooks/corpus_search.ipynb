# %%
import pandas as pd

excel_path = "../data/spreadsheets/street_signs_taipei_sheets.xlsx"

observations = pd.read_excel(
    excel_path,
    sheet_name="OBSERVATION"
)

search_df = observations[
    [
        "sign_id",
        "observation_id",
        "survey_id",
        "observation_date",
        "sign_latitude",
        "sign_longitude",
        "sign_content",
        "sign_status",
        "sign_condition",
        "sign_photo_filename",
        "observation_notes"
    ]
].copy()

search_df["observation_date"] = pd.to_datetime(
    search_df["observation_date"],
    errors="coerce"
)

search_df["month"] = (
    search_df["observation_date"]
    .dt.to_period("M")
    .astype(str)
)

from itables import show

display_df = search_df[
    [
        "sign_id",
        "observation_id",
        "survey_id",
        "month",
        "sign_content",
        "sign_status",
        "sign_condition",
        "sign_photo_filename"
    ]
]

display_df["sign_content"] = (
    display_df["sign_content"]
    .fillna("")
    .str.slice(0, 100)
)

show(
    display_df,
    paging=True,
    columnDefs=[
        {
            "targets": "_all",
            "className": "dt-left"
        }
    ]
)
# Out:
# C:\Users\omistaja\AppData\Local\Temp\ipykernel_15696\3810691704.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   display_df["sign_content"] = (
# <!--| quarto-html-table-processing: none -->
# <table id="itables_426a632b_d5c6_4d4f_8279_48caef271579" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_426a632b_d5c6_4d4f_8279_48caef271579_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>sign_id</th>
#       <th style="border:1px solid #ddd;padding:8px">observation_id</th>
#       <th style="border:1px solid #ddd;padding:8px">survey_id</th>
#       <th style="border:1px solid #ddd;padding:8px">month</th>
#       <th style="border:1px solid #ddd;padding:8px">sign_content</th>
#       <th style="border:1px solid #ddd;padding:8px">sign_status</th>
#       <th style="border:1px solid #ddd;padding:8px">sign_condition</th>
#       <th style="border:1px solid #ddd;padding:8px">sign_photo_filename</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">SG0001</td><td style="border:1px solid #ddd;padding:8px">O0001</td><td style="border:1px solid #ddd;padding:8px">S0001a</td><td style="border:1px solid #ddd;padding:8px">2026-08</td><td style="border:1px solid #ddd;padding:8px">西拉雅大道\n#水路\nXi aya Blvd\n生能保護區\n商务会馆\nEolgicalPpration ARea\nCommercial Center\n道爺湖\n道爺古墓遺址\nArcheedbocaSShe.</td><td style="border:1px solid #ddd;padding:8px">Present</td><td style="border:1px solid #ddd;padding:8px">Bad</td><td style="border:1px solid #ddd;padding:8px">SG0001_O0001_P0001.jpg</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px