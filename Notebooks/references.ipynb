# %% [markdown]
# # References

# %% [markdown]
# Hitchcock, M., King, V. T., & Parnwell, M. J. (2010). Heritage Tourism in Southeast Asia. Heritage tourism in southeast Asia, 1-27.

# %% [markdown]
# Pratt, M. L. (1991). Arts of the contact zone. profession, 34, 19.

# %% [markdown]
# Scollon, R., & Scollon, S. B. (2003). Discourses in place: Language in the material world. Psychology Press.

# %% [markdown]
# Yoshimura, M., & Wall, G. (2010). The reconstruction of Atayal identity in Wulai, Taiwan. Heritage Tourism in Southeast Asia, 49-71.

# %% [markdown]
# #### AI disclosure statement:
#
# Generative AI was used to refine and debug pieces of code. It was not used for any other aspect of planning or content creation.
