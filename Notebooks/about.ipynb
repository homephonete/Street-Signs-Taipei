# %% [markdown]
# # Why study street signs?
#
# Street signs are indexical; their meanings are based on their material location and social context and help us analyze the relationship between the two in a given place. (Scollon & Scollon, 2003).
