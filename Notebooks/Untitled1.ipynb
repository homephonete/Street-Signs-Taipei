# %%
import sys
print(sys.executable)

import sys
# !{sys.executable} -m pip install paddleocr

import sys
# !{sys.executable} -m pip install paddlepaddle

from paddleocr import PaddleOCR
# Out:
# C:\Users\omistaja\anaconda3\python.exe
# ...
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `DISABLE_MODEL_SOURCE_CHECK` to `True`.

# %%
# %pip uninstall -y paddleocr paddlepaddle paddlex
# %pip install paddlepaddle==3.2.0 paddleocr==3.3.3
# Out:
# Found existing installation: paddleocr 3.3.3
# Uninstalling paddleocr-3.3.3:
#   Successfully uninstalled paddleocr-3.3.3
# Found existing installation: paddlepaddle 3.2.0
# Uninstalling paddlepaddle-3.2.0:
#   Successfully uninstalled paddlepaddle-3.2.0
# Found existing installation: paddlex 3.3.13
# Uninstalling paddlex-3.3.13:
#   Successfully uninstalled paddlex-3.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import gc
from pathlib import Path

os.environ["FLAGS_enable_pir_api"] = "0"

from paddleocr import PaddleOCR

input_dir = Path(r"C:/Users/omistaja/Desktop/AS Project/Data/Photos/S0002")
output_dir = Path(r"C:/Users/omistaja/Desktop/AS Project/Data/OCR_results")
output_dir.mkdir(exist_ok=True)

ocr = PaddleOCR(
    enable_mkldnn=False,
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False
)

extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

files = [
    f for f in input_dir.iterdir()
    if f.suffix.lower() in extensions
]

print(f"Found {len(files)} images")

for i, file in enumerate(files, start=1):
    print(f"{i}/{len(files)}: {file.name}")

    try:
        results = ocr.predict(
            input=str(file),
            text_det_limit_type="max",
            text_det_limit_side_len=1280
        )

        for result in results:
            result.save_to_json(str(output_dir))

        del results
        gc.collect()

    except Exception as e:
        print(f"FAILED: {file.name}")
        print(e)
# Out:
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_det`.
# Creating model: ('PP-OCRv5_server_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_rec`.
# Found 443 images
# 1/443: SG0053_O0053_P0087.JPG
# 2/443: SG0054_O0054_P0088.JPG
# 3/443: SG0055a_O0055a_P0089.JPG
# 4/443: SG0055b_O0055b_P0090.JPG
# 5/443: SG0056a_O0056a_P0091.JPG
# 6/443: SG0056b_O0056b_P0092.JPG
# 7/443: SG0057_O0057_P0093.JPG
# 8/443: SG0058_O0058_P0094.JPG
# 9/443: SG0059_O0059_P0095.JPG
# 10/443: SG0060a-b_O0060a-b_P0096.JPG
# 11/443: SG0061_O0061_P0097.JPG
# 12/443: SG0062_O0062_P0098.JPG
# 13/443: SG0063_O0063_P0099.JPG
# 14/443: SG0064_O0064_P0100.JPG
# 15/443: SG0065_O0065_P0101.JPG
# 16/443: SG0066_O0066_P0102.JPG
# ...

# %%
import os
import gc
from pathlib import Path
import pandas as pd

os.environ["FLAGS_enable_pir_api"] = "0"

from paddleocr import PaddleOCR

input_dir = Path(
    r"C:/Users/omistaja/Desktop/AS Project/Data/Photos/S0001a"
)

output_excel = (
    r"C:\Users\omistaja\Desktop\AS Project\Data\ocr_results_S0001a.xlsx"
)

ocr = PaddleOCR(
    enable_mkldnn=False,
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False
)

extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

files = [
    f for f in input_dir.iterdir()
    if f.suffix.lower() in extensions
]

rows = []

for i, file in enumerate(files, start=1):

    print(f"{i}/{len(files)}: {file.name}")

    try:
        results = ocr.predict(
            input=str(file),
            text_det_limit_type="max",
            text_det_limit_side_len=1280
        )

        # Collect all recognized text from this image
        text_lines = []

        for result in results:
            data = result.json

            # PaddleOCR 3.x
            rec_texts = data["res"].get("rec_texts", [])
            text_lines.extend(rec_texts)

        rows.append({
            "filename": file.name,
            "text": "\n".join(text_lines)
        })

        del results
        gc.collect()

    except Exception as e:

        print(f"FAILED: {file.name}")

        rows.append({
            "filename": file.name,
            "text": "",
            "error": str(e)
        })


# Create table
df = pd.DataFrame(rows)

# Save to Excel
df.to_excel(output_excel, index=False)

print("Finished!")
print(output_excel)
# Out:
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_det`.
# Creating model: ('PP-OCRv5_server_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_rec`.
# 1/53: SG0001_O0001_P0001.JPG
# 2/53: SG0001_O0001_P0031.JPG
# 3/53: SG0002_O0002_P0002.JPG
# 4/53: SG0002_O0002_P0032.JPG
# 5/53: SG0003_O0003_P0003.JPG
# 6/53: SG0003_O0003_P0033.JPG
# 7/53: SG0004_O0004_P0004.JPG
# 8/53: SG0004_O0004_P0034.JPG
# 9/53: SG0005_O0005_P0005.JPG
# 10/53: SG0005_O0005_P0035.JPG
# 11/53: SG0006_O0006_P0006.JPG
# 12/53: SG0006_O0006_P0036.JPG
# 13/53: SG0007_O0007_P0007.JPG
# 14/53: SG0007_O0007_P0037.JPG
# 15/53: SG0008_O0008_P0008.JPG
# 16/53: SG0008_O0008_P0038.JPG
# 17/53: SG0009-0010_O0009-0010_P0039.JPG
# ...

# %%
import os
import gc
from pathlib import Path
import pandas as pd

os.environ["FLAGS_enable_pir_api"] = "0"

from paddleocr import PaddleOCR

input_dir = Path(
    r"C:/Users/omistaja/Desktop/AS Project/Data/Photos/S0002"
)

output_excel = (
    r"C:\Users\omistaja\Desktop\AS Project\Data\ocr_results.xlsx"
)

ocr = PaddleOCR(
    enable_mkldnn=False,
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False
)

extensions = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"}

files = [
    f for f in input_dir.iterdir()
    if f.suffix.lower() in extensions
]

rows = []

for i, file in enumerate(files, start=1):

    print(f"{i}/{len(files)}: {file.name}")

    try:
        results = ocr.predict(
            input=str(file),
            text_det_limit_type="max",
            text_det_limit_side_len=1280
        )

        # Collect all recognized text from this image
        text_lines = []

        for result in results:
            data = result.json

            # PaddleOCR 3.x
            rec_texts = data["res"].get("rec_texts", [])
            text_lines.extend(rec_texts)

        rows.append({
            "filename": file.name,
            "text": "\n".join(text_lines)
        })

        del results
        gc.collect()

    except Exception as e:

        print(f"FAILED: {file.name}")

        rows.append({
            "filename": file.name,
            "text": "",
            "error": str(e)
        })


# Create table
df = pd.DataFrame(rows)

# Save to Excel
df.to_excel(output_excel, index=False)

print("Finished!")
print(output_excel)
# Out:
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_det`.
# Creating model: ('PP-OCRv5_server_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\omistaja\.paddlex\official_models\PP-OCRv5_server_rec`.
# 1/443: SG0053_O0053_P0087.JPG
# 2/443: SG0054_O0054_P0088.JPG
# 3/443: SG0055a_O0055a_P0089.JPG
# 4/443: SG0055b_O0055b_P0090.JPG
# 5/443: SG0056a_O0056a_P0091.JPG
# 6/443: SG0056b_O0056b_P0092.JPG
# 7/443: SG0057_O0057_P0093.JPG
# 8/443: SG0058_O0058_P0094.JPG
# 9/443: SG0059_O0059_P0095.JPG
# 10/443: SG0060a-b_O0060a-b_P0096.JPG
# 11/443: SG0061_O0061_P0097.JPG
# 12/443: SG0062_O0062_P0098.JPG
# 13/443: SG0063_O0063_P0099.JPG
# 14/443: SG0064_O0064_P0100.JPG
# 15/443: SG0065_O0065_P0101.JPG
# 16/443: SG0066_O0066_P0102.JPG
# 17/443: SG0067_O0067_P0103.JPG
# ...
